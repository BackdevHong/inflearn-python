# %%
my_int = 1 # ( = ) 할당

# %%
my_int
# Out:
# 1

# %%
my_int * 100
# Out:
# 100

# %%
sdlkfjsdalkfj_asdfkjl = 1

# %%
sdlkfjsdalkfj_asdfkjl
# Out:
# 1

# %%
python = 1
PYTHON = 2

# %%
python
# Out:
# 1

# %%
PYTHON
# Out:
# 2

# %%
홍인성 = 1

# %%
김왼손 = 20

# %%
홍인성
# Out:
# 1

# %%
김왼손
# Out:
# 20

# %%
1python = 2
# Out:
#   Cell In[16], line 1
#     1python = 2
#     ^
# SyntaxError: invalid decimal literal

# %%
p1ython = 1

# %%
p1ython
# Out:
# 1

# %%
my int = 2
# Out:
#   Cell In[19], line 1
#     my int = 2
#        ^
# SyntaxError: invalid syntax
