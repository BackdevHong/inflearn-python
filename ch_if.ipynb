# %%
input_name = '홍인성'

# %%
if input_name == '홍인성':
  print('맞네', input_name)
# Out:
# 맞네 홍인성

# %%
if input_name == '홍안성':
  print('맞네', input_name)

# %%
if input_name == '홍인성':
  print('당신은 홍인성이군요?')
elif input_name == '홍안성':
  print('당신은 홍안성이군요?')
else:
  print('넌 누구야?')
# Out:
# 당신은 홍인성이군요?
