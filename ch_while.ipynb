# %%
# while

# %%
count = 0

# %%
while count < 3:
  print('횟수:', count)
  count += 1
# Out:
# 횟수: 0
# 횟수: 1
# 횟수: 2

# %%
while count < 3:
  print('횟수:', count)
  # count += 1
# Out:
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# 횟수: 0
# ...

# %%
# continue, break

# %%
while count < 10:
  count += 1
  if (count < 4):
    continue
  print('횟수:', count)
  if (count == 8):
    break
# Out:
# 횟수: 4
# 횟수: 5
# 횟수: 6
# 횟수: 7
# 횟수: 8
