# %%
# Operator

# %%
# Assign (할당 연산자)

# %%
count = 0

# %%
count
# Out:
# 0

# %%
count = 1

# %%
count
# Out:
# 1

# %%
count = count + 1

# %%
count
# Out:
# 2

# %%
count += 1 # += 증가 연산자

# %%
count
# Out:
# 3

# %%
count = count - 1

# %%
count
# Out:
# 2

# %%
count -= 1

# %%
count
# Out:
# 1

# %%
# Arithmetic

# %%
3 + 3
# Out:
# 6

# %%
20 - 5
# Out:
# 15

# %%
6 * 2
# Out:
# 12

# %%
12 / 3
# Out:
# 4.0

# %%
3 ** 2
# Out:
# 9

# %%
4 ** 3 # ** = 제곱
# Out:
# 64

# %%
7 / 3
# Out:
# 2.3333333333333335

# %%
7 // 3 # 몫
# Out:
# 2

# %%
7 % 2 # 나머지
# Out:
# 1

# %%
numbers = [1, 2, 3, 4, 5, 6, 7]

# %%
for number in numbers:
  print(number)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
if 1 % 2 == 1:
  print("홀수")
# Out:
# 홀수

# %%
for number in numbers:
  if number % 2 == 1:
    print(number, "는 홀수!")
  else:
    print(number, "는 짝수!")
# Out:
# 1 는 홀수!
# 2 는 짝수!
# 3 는 홀수!
# 4 는 짝수!
# 5 는 홀수!
# 6 는 짝수!
# 7 는 홀수!

# %%
# String Operator

# %%
'김왼손' + 'X' + '엘리스'
# Out:
# '김왼손X엘리스'

# %%
'안녕하세요' + '반갑습니다'
# Out:
# '안녕하세요반갑습니다'

# %%
'안녕하세요' + ' ' + '반갑습니다'
# Out:
# '안녕하세요 반갑습니다'

# %%
'안녕' * 3
# Out:
# '안녕안녕안녕'

# %%
'안녕' * 10
# Out:
# '안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕'

# %%
'안녕 ' * 5
# Out:
# '안녕 안녕 안녕 안녕 안녕 '

# %%
# Comparison

# %%
1 < 2
# Out:
# True

# %%
2 < 1
# Out:
# False

# %%
1 != 1
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
4 <= 6
# Out:
# True

# %%
5 <= 5
# Out:
# True

# %%
# Logical

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %%
height = 120
age = 8

# %%
height > 140 and age > 10
# Out:
# False

# %%
height = 190
age = 9

# %%
height > 140 and age > 10
# Out:
# False

# %%
height = 150
age = 32

# %%
height > 140 and age > 10
# Out:
# True

# %%
# Membership

# %%
김왼손과_집단지성들 = ["홍인성", "요거트", "라면", "피자"]

# %%
'홍인성' in 김왼손과_집단지성들
# Out:
# True

# %%
'라이터' in 김왼손과_집단지성들
# Out:
# False

# %%
'라이터' not in 김왼손과_집단지성들
# Out:
# True

# %%
'홍인성' not in 김왼손과_집단지성들
# Out:
# False
