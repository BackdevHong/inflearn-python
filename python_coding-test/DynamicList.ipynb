# %%
a = [1, 2, 3] # O(1)

# %%
a[0] # random access O(1)
# Out:
# 1

# %%
a[1] = 9 # O(1)

# %%
a[1]
# Out:
# 9

# %%
a.append(4)

# %%
a.append(5) # O(1)

# %%
a.append(6)

# Resizing O(n)

# %%
a
# Out:
# [1, 9, 3, 4, 5, 6]

# %%
a.pop() # O(1)
# Out:
# 6

# %%
a.insert(1, 10) # O(n)
