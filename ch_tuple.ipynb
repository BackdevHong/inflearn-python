# %%
my_tuple = ()

# %%
my_tuple
# Out:
# ()

# %%
print(type(my_tuple))
# Out:
# <class 'tuple'>

# %%
my_tuple = (1, 2, 3)

# %%
my_tuple = 1, 2, 3

# %%
my_tuple
# Out:
# (1, 2, 3)

# %%
print(type(my_tuple))
# Out:
# <class 'tuple'>

# %%
# Packing, Unpacking

# %%
my_tuple = 1, 2, 3

# %%
num1, num2, num3 = my_tuple

# %%
num1
# Out:
# 1

# %%
num2
# Out:
# 2

# %%
num3
# Out:
# 3

# %%
num1 = 1
num2 = 2

# %%
num1, num2 = num2, num1

# %%
num1
# Out:
# 2

# %%
num2
# Out:
# 1
