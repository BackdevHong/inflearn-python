# %%
my_str = "문자열"

# %%
print(my_str)
# Out:
# 문자열

# %%
print(type(my_str))
# Out:
# <class 'str'>

# %%
my_str = 'AWS'

# %%
print(my_str)
# Out:
# AWS

# %%
print(type(my_str))
# Out:
# <class 'str'>

# %%
my_str = """홍인성
유성
라일락
"""

# %%
my_str # \n - 줄바꿈
# Out:
# '홍인성\n유성\n라일락\n'

# %%
# Formatting

# %%
# %d, %f, %s

# %%
my_str = "My Name is %s" % "Hong In Sung"

# %%
my_str
# Out:
# 'My Name is Hong In Sung'

# %%
'%d %d' % (1, 2)
# Out:
# '1 2'

# %%
"%.2f %.2f" % (3.14, 3.2)
# Out:
# '3.14 3.20'

# %%
'My name is {}'.format('홍인성')
# Out:
# 'My name is 홍인성'

# %%
'{} x {} = {}'.format(2, 1, 2*1)
# Out:
# '2 x 1 = 2'

# %%
'{1} x {0} = {2}'.format(2, 3, 2*3)
# Out:
# '3 x 2 = 6'

# %%
# Indexing

# %%
my_name = "Python"

# %%
my_name[3] # p(0)y(1)t(2)h(3)o(4)n(5)
# Out:
# 'h'

# %%
my_name[-1]
# p(0, -6)y(1, -5)t(2, -4)h(3, -3)o(4, -2)n(5, -1)
# Out:
# 'n'

# %%
# Slicing

# %%
my_name = "김왼손의 왼손코딩"

# %%
my_name[5:7]
# Out:
# '왼손'

# %%
my_name[:3]
# Out:
# '김왼손'

# %%
my_name[3:]
# Out:
# '의 왼손코딩'

# %%
# Split

# %%
my_name.split()
# Out:
# ['김왼손의', '왼손코딩']

# %%
fruit_str = '거봉 수박 포도 복숭아 망고 딸기 배 참외 찹쌀떡'

# %%
fruit_str
# Out:
# '거봉 수박 포도 복숭아 망고 딸기 배 참외 찹쌀떡'

# %%
fruits = fruit_str.split()

# %%
fruits
# Out:
# ['거봉', '수박', '포도', '복숭아', '망고', '딸기', '배', '참외', '찹쌀떡']

# %%
# Docstring

# %%
# 주석

# %%
"""이것도 주석입니다"""
# Out:
# '이것도 주석입니다'

# %%
# end

# %%
print('집단지성', end='/')
# Out:
# 집단지성/

# %%
print('집단지성', end='미운코딩세끼')
# Out:
# 집단지성미운코딩세끼

# %%
# Escape Code

# %%
print('미운코딩세끼의\n집단지성들') # 줄바꿈
# Out:
# 미운코딩세끼의
# 집단지성들

# %%
print('미운코딩세끼의\t집단지성들') # 탭
# Out:
# 미운코딩세끼의	집단지성들

# %%
print('미운코딩세끼의\t집단\n지성들')
# Out:
# 미운코딩세끼의	집단
# 지성들

# %%
print('미운', end='\t')
print('코딩')
# Out:
# 미운	코딩
