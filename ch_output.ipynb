# %%
print()

# %%
print('Hello World')
# Out:
# Hello World

# %%
print(1)
# Out:
# 1

# %%
print([1, 2, 3])
# Out:
# [1, 2, 3]

# %%
print)1(
# Out:
#   Cell In[7], line 1
#     print)1(
#          ^
# SyntaxError: unmatched ')'

# %%
print(1)
# Out:
# 1

# %%
print(1, 2)
# Out:
# 1 2

# %%
print(1, 2, 3)
# Out:
# 1 2 3

# %%
print(1,2,3)
# Out:
# 1 2 3

# %%
print(123)
# Out:
# 123

# %%
print('python')
# Out:
# python

# %%
print("My Name is", "Hong In Sung")
# Out:
# My Name is Hong In Sung
