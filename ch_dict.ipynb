# %%
# Dictionary

# %%
my_dict = {}

# %%
my_dict
# Out:
# {}

# %%
print(type(my_dict))
# Out:
# <class 'dict'>

# %%
my_dict[0] = 'a'

# %%
my_dict
# Out:
# {0: 'a'}

# %%
my_dict['b'] = 2

# %%
my_dict
# Out:
# {0: 'a', 'b': 2}

# %%
my_dict['학생1'] = '홍인성'

# %%
my_dict
# Out:
# {0: 'a', 'b': 2, '학생1': '홍인성'}

# %%
my_dict['b']
# Out:
# 2

# %%
# Method

# %%
my_dict.values()
# Out:
# dict_values(['a', 2, '홍인성'])

# %%
for std in my_dict.values():
  print(std)
# Out:
# a
# 2
# 홍인성

# %%
my_dict.keys()
# Out:
# dict_keys([0, 'b', '학생1'])

# %%
for std in my_dict.keys():
  print(std)
# Out:
# 0
# b
# 학생1

# %%
my_dict.items()
# Out:
# dict_items([(0, 'a'), ('b', 2), ('학생1', '홍인성')])

# %%
for key, val in my_dict.items():
  print(key, val)
# Out:
# 0 a
# b 2
# 학생1 홍인성
