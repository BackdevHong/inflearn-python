# %%
# List

# %%
my_list = []

# %%
my_list
# Out:
# []

# %%
print(type(my_list))
# Out:
# <class 'list'>

# %%
my_list = [1, 2, 3]

# %%
my_list
# Out:
# [1, 2, 3]

# %%
std = ['홍인성', '홍인성2', '홍인성3']

# %%
std
# Out:
# ['홍인성', '홍인성2', '홍인성3']

# %%
# append

# %%
std.append('시현')

# %%
std
# Out:
# ['홍인성', '홍인성2', '홍인성3', '시현']

# %%
std.append("난방")

# %%
std
# Out:
# ['홍인성', '홍인성2', '홍인성3', '시현', '난방']

# %%
animals = []

# %%
animals.append('코알라')

# %%
animals.append('하이에나')

# %%
animals.append('바다소')

# %%
animals.append('땅다람쥐')

# %%
animals
# Out:
# ['코알라', '하이에나', '바다소', '땅다람쥐']

# %%
humans.append('조희진')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 humans.append('조희진')
#
# NameError: name 'humans' is not defined

# %%
humans = []

# %%
humans.append('찹살떡')

# %%
humans
# Out:
# ['찹살떡']

# %%
# Indexing

# %%
animals
# Out:
# ['코알라', '하이에나', '바다소', '땅다람쥐']

# %%
animals.append('스컹크')
animals.append('바다코끼리')
animals.append('아나콘다')

# %%
animals
# Out:
# ['코알라', '하이에나', '바다소', '땅다람쥐', '스컹크', '바다코끼리', '아나콘다']

# %%
animals[3]
# Out:
# '땅다람쥐'

# %%
animals[4]
# Out:
# '스컹크'

# %%
del animals[4]

# %%
animals
# Out:
# ['코알라', '하이에나', '바다소', '땅다람쥐', '바다코끼리', '아나콘다']

# %%
# Slicing

# %%
animals[0:2]
# Out:
# ['코알라', '하이에나']

# %%
animals[1:3]
# Out:
# ['하이에나', '바다소']

# %%
# Sort

# %%
animals.sort()

# %%
animals
# Out:
# ['땅다람쥐', '바다소', '바다코끼리', '아나콘다', '코알라', '하이에나', '바다소']

# %%
# Count

# %%
animals.append("바다소")

# %%
animals.count('바다소')
# Out:
# 2

# %%
animals.count('코알라')
# Out:
# 1

# %%
len(animals)
# Out:
# 7
