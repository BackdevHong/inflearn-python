# %%
# Module

# %%
import random

# %%
students = ["홍인성", "망고", "수박", "회전", "유성", "쌍룡"]

# %%
print(random.choice(students))
# Out:
# 수박

# %%
print(random.choice(students))
# Out:
# 회전

# %%
print(random.choice(students))
# Out:
# 쌍룡

# %%
print(random.choice(students))
# Out:
# 수박

# %%
print(random.choice(students))
# Out:
# 쌍룡

# %%
print(random.choice(students))
# Out:
# 홍인성

# %%
print(random.sample(students, 2))
# Out:
# ['쌍룡', '망고']

# %%
print(random.sample(students, 2))
# Out:
# ['망고', '홍인성']

# %%
print(random.sample(range(1, 46), 6))
# Out:
# [27, 39, 37, 15, 5, 4]

# %%
print(random.sample(range(1, 46), 6))
# Out:
# [17, 29, 5, 44, 8, 37]

# %%
print(random.sample(range(1, 46), 6))
# Out:
# [14, 36, 12, 6, 24, 9]

# %%
print(random.sample(range(1, 46), 6))
# Out:
# [25, 18, 4, 22, 10, 28]

# %%
print(random.sample(range(1, 46), 6))
# Out:
# [22, 7, 19, 9, 25, 17]

# %%
print(random.randint(8, 10))
# Out:
# 10

# %%
print(random.randint(8, 10))
# Out:
# 9

# %%
print(random.randint(8, 10))
# Out:
# 8

# %%
print(random.randint(8, 10))
# Out:
# 8

# %%
print(random.randint(8, 10))
# Out:
# 9

# %%
print(random.randint(8, 10))
# Out:
# 10
