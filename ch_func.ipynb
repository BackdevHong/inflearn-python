# %%
# Function

# %%
def add(num1, num2):
  return num1 + num2

# %%
add(1, 2)
# Out:
# 3

# %%
def add_mul(num1, num2):
  return num1 + num2, num1 * num2

# %%
add_mul(1, 2)
# Out:
# (3, 2)

# %%
print(type(add_mul(1, 2)))
# Out:
# <class 'tuple'>

# %%
my_add, my_mul = add_mul(1, 2)

# %%
my_add
# Out:
# 3

# %%
my_mul
# Out:
# 2
