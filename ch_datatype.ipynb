# %%
# Numeric

# %%
1, 2, 3 # 정수
3.14, 2.4 # 실수

# %%
my_int = 3
print(my_int)
# Out:
# 3

# %%
my_float = 3.14
print(my_float)
# Out:
# 3.14

# %%
print(type(my_int)) # 정수 int
print(type(my_float)) # 실수 float
# Out:
# <class 'int'>
# <class 'float'>

# %%
1 + 2, 3 + 3
# Out:
# (3, 6)

# %%
# String

# %%
'Hello'
# Out:
# 'Hello'

# %%
"Hello"
# Out:
# 'Hello'

# %%
'adsf"
# Out:
#   Cell In[14], line 1
#     'adsf"
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('hello world')
# Out:
# hello world

# %%
# Boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
my_bool = True

# %%
print(my_bool)
# Out:
# True

# %%
# List

# %%
my_list = []

# %%
my_list = [1, 2, 3]

# %%
students = ["홍인성", "유니", "부키", "히나"]

# %%
students
# Out:
# ['홍인성', '유니', '부키', '히나']

# %%
for std in students:
  print(std)
# Out:
# 홍인성
# 유니
# 부키
# 히나

# %%
import random
print(random.choice(students))
# Out:
# 유니

# %%
students.append("강지")
students.append("라일락")

# %%
students
# Out:
# ['홍인성', '유니', '부키', '히나', '강지', '라일락', '강지', '라일락']

# %%
students[6] = "타비"

# %%
students
# Out:
# ['홍인성', '유니', '부키', '히나', '강지', '라일락', '타비', '라일락']

# %%
# Tuple

# %%
my_tuple = ("라면", "김밥", "볶음밥")

# %%
my_tuple[0] = "짜장면" # 수정 불가능
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 my_tuple[0] = "짜장면" # 수정 불가능
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Dictionary

# %%
my_dict = {
  '인성' : '남',
  '감규리' : '남',
  '히나' : '여',
  '부키' : '여'
}

# %%
my_dict["인성"]
# Out:
# '남'

# %%
my_dict["부키"]
# Out:
# '여'

# %%
my_dict["감규리"] = "여"
my_dict["감규리"]
# Out:
# '여'

# %%
# Convert

# %%
my_int = 1
my_str = "coding"

# %%
type(my_int)
# Out:
# int

# %%
float(my_int)
# Out:
# 1.0

# %%
str(my_int)
# Out:
# '1'

# %%
bool(my_int)
# Out:
# True

# %%
list(my_str)
# Out:
# ['c', 'o', 'd', 'i', 'n', 'g']
